# %% [markdown]
# # qiskit 基础
#
# ## 1 Introdution
#
# Qiskit is not only could access the code to real quantum hardware(IBM) by api, but also can to simulate the quantum program via classical computer similar as **Qulacs(Qulacs is better)**
#
# ## 2 installation
#
# ### 2.1 real quatum comp
# #### 2.1.1 IBM
#
# * Registration: https://www.ibm.com/quantum
#
# It seems there is a 30-day probation period...
# #### 2.1.2 quark
#
# * quarkstudio: https://quarkstudio.readthedocs.io/en/latest/#3-quick-guide
# * 超导: https://quafu-sqc.baqis.ac.cn/framework/home
#
# pHCY3u..ukZUs5Smk9QZRkb`WmR3[xGGdWSoOX[e.fO/Rg2FUO3NkN35jOydkN5VUP3dUN7JDd5WnJtJjOypUO1pEOyBTPz1jNy1TOzBkNjpkJ1GXbjxDN7JDcm[Y[tKDMj13ck6TdyCVN4hkOzh{OyRkNjpkJzW3d2Kzf
#
# you could copy the api at any time
#
# ### 2.2 qiskit
#
# Create your visual environment, install qiskit(I have writing the visual path in ~/.profile).
#
# qulacs is beter quality

# %%
# !pip install qiskit
# we do not need gpu, because the gpu is fundamentally not suitable for quantum circuit simulation, and the cpu is already very fast for our purposes
# !pip install qiskit_aer
# !pip install qiskit[visualization]
# new version demands this package for IBMQ account management
# !pip install qiskit-ibm-runtime 
# !pip install qiskit-algorithms
# 如果有gpu可以考虑cuQuantum

# %%
from cirqqulacs import QulacsSimulator
print("安装成功")
# Out:
# 安装成功

# %%
import qiskit
qiskit.__version__
# Out:
# '2.3.0'

# %% [markdown]
# ### 2.3 api registration
# #### 2.3.1 quafa
#
# > my quafu api key: 'Jx:t2EeEq{g:FZBB7H46S548MyDs2oFV.3nvGVYDyY4/:WUN{hUP{5TN1FkO4VUP3dUN7JDd5WnJtJTN1pUO2pkNyBTPz1jNy1TOzBkNjpkJ1GXbjxDN7JDcm[Y[tKDMj13ck6DcqGXctGHemCIR5l{O5BkOzZ{O5FUZjpkJzW3d2Kzf'
#
# * save the api

# %%
# !pip install quarkstudio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 357.8 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.3/554.3 kB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.6/427.6 kB 2.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 917.0 kB/s eta 0:00:000:01:00:01
# ...

# %%
from quark import Task
token = "5tEpqqrcW1H.xS9SnQZ4tSZsHkUEcEjtcOLgTiHT1b9/:SkN2VkO{5DNzJ{OyRkN4dUN7JDd5WnJtJDNxp{OxpENyBTN{1TNx1jOzBkNjpkJ1GXbjxDN7JDcm[Y[tKDMj13ck6DcqGXctGHemCIR5l{O5BkOzZ{O5FUZjpkJzW3d2Kzf"
tmgr = Task(token)

# %% [markdown]
# 当然可以加入系统变量：export QUARK_API_TOKEN='your_token_here'

# %%
from quark import Task
import os
token = os.getenv('QUARK_API_TOKEN')
tmgr = Task(token)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 4
#       2 import os
#       3 token = os.getenv('QUARK_API_TOKEN')
# ----> 4 tmgr = Task(token)
#
# File ~/.python/lib/python3.12/site-packages/quark/__init__.py:42, in Task.__init__(self, token)
#      40 def __init__(self, token: str = '') -> None:
#      41     self.token = os.getenv('QPU_API_TOKEN', token)
# ---> 42     assert self.token, 'token cannot be empty!'
#      44     v = self.verify()
#      45     if isinstance(v, dict):
#
# AssertionError: token cannot be empty!

# %% [markdown]
# * 当前任务数。

# %%
display(tmgr.status())
# Out:
# {'Baihua': 0,
#  'Yudu': 2,
#  'Dongling': 0,
#  'Haituo': 0,
#  'Baiwang': 0,
#  'Fenghuang': 0,
#  'Haituo-2': 'Maintenance',
#  'Hongluo': 'Calibrating',
#  'Jiu': 'Maintenance',
#  'Ling': 'Maintenance',
#  'Lingkai-1': 'Calibrating',
#  'Lingkai-2': 'Calibrating',
#  'Miaofeng': 'Maintenance',
#  'Shenglian': 'Calibrating',
#  'Xiang': 'Maintenance'}

# %% [markdown]
# #### 2.3.2 IBM

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
IBM_API_TOKEN = 'N7Xu2261xeB3CilWxUt3Khsm6h0ezbYdbfZvVau5N4qD'
QiskitRuntimeService.save_account(IBM_API_TOKEN, overwrite=True)

# %% [markdown]
# check the account

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# 创建服务实例（自动加载已保存的账户）
service = QiskitRuntimeService()

# 检查活动账户
print("Active account:", service.active_account())

# 验证后端列表（确认账户有效）
print("\nAvailable backends:")
for backend in service.backends():
    print(f"- {backend.name} | Status: {backend.status().operational}")
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-02-06 13:16:16,890: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-02-06 13:16:16,891: Loading instance: open-instance, plan: open
# Active account: {'channel': 'ibm_quantum_platform', 'url': 'https://cloud.ibm.com', 'token': 'N7Xu2261xeB3CilWxUt3Khsm6h0ezbYdbfZvVau5N4qD', 'verify': True, 'private_endpoint': False}
#
# Available backends:
# - ibm_fez | Status: True
# - ibm_torino | Status: True
# - ibm_marrakesh | Status: True

# %%
service.backends()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 service.backends()
#
# NameError: name 'service' is not defined
